# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
interference_events = pd.read_csv('data/interference-measurements-by-country-2019-sanity.csv')\

# %%
interference_events.sort_values(by='strict_rate', ascending=False)
# Out:
#     country_code  num_confirmed_interference  num_anomaly  \
# 95            IR                       11084        12789
# 171           SA                         690          903
# 1             AE                         292          401
# 169           RU                      230863       431976
# 167           RO                         920         1617
# 93            IN                        1895        28438
# 162           PT                         550         1276
# 18            BE                          93          416
# 141           MY                         126          421
# 79            GR                         118          396
# 165           QA                           1           30
# 107           KR                          40         5207
# 51            DK                           1          203
# 97            IT                          18         7201
# 68            GB                           2         2999
# 149           NP                           0           21
# 144           NE                           0            0
# 160           PR                           0            6
# 159           PL                           0         6072
# 145           NG                           0         2057
# 146           NI                           0            5
# 147           NL                           0        28740
# 148           NO                           0         6004
# 158           PK                           0         9604
# 150           NR                           0            0
# 156           PG                           0            3
# 151           NZ                           0           21
# 152           OM                           0           11
# 157           PH                           0          114
# 143           NC                           0            0
# ..           ...                         ...          ...
# 109           KY                           0            1
# 111           LA                           0            0
# 112           LB                           0          164
# 84            HK                           0          820
# 83            GY                           0            0
# 82            GW                           0            0
# 67            GA                           0            1
# 57            EG                           0         3176
# 58            ER                           0            0
# 59            ES                           0         1644
# 60            ET                           0          273
# 61            EU                           0          241
# 62            FI                           0          457
# 63            FJ                           0            0
# 64            FM                           0            0
# 65            FO                           0            0
# 66            FR                           0        32368
# 69            GE                           0           13
# 81            GU                           0            3
# 70            GF                           0            0
# 71            GG                           0            0
# 72            GH                           0            1
# 73            GI                           0            0
# 74            GL                           0            1
# 75            GM                           0            4
# 76            GN                           0            1
# 77            GP                           0            0
# 78            GQ                           0            0
# 80            GT                           0            3
# 219           ZZ                           0        41808
#
#      num_no_confirmed_interference  strict_rate  loose_rate
# 95                           27413     0.287919    0.620126
# 171                           3700     0.157175    0.362870
# 1                             1745     0.143348    0.340206
# 169                        2328317     0.090210    0.259004
# 167                          32478     0.027547    0.075963
# 93                          102413     0.018167    0.290802
# 162                          46383     0.011719    0.038907
# 18                            8235     0.011167    0.061119
# 141                          11513     0.010826    0.046997
# 79                           28130     0.004177    0.018196
# 165                            559     0.001786    0.055357
# 107                          93777     0.000426    0.055928
# 51                            3104     0.000322    0.065700
# 97                          104319     0.000173    0.069189
# 68                          121242     0.000016    0.024752
# 149                            389     0.000000    0.053985
# 144                            108     0.000000    0.000000
# 160                            246     0.000000    0.024390
# 159                          38546     0.000000    0.157526
# 145                          29444     0.000000    0.069861
# 146                            559     0.000000    0.008945
# 147                          85496     0.000000    0.336156
# 148                          26132     0.000000    0.229757
# 158                          84325     0.000000    0.113893
# 150                              3     0.000000    0.000000
# 156                             23     0.000000    0.130435
# 151                           1125     0.000000    0.018667
# 152                            374     0.000000    0.029412
# 157                           6940     0.000000    0.016427
# 143                             42     0.000000    0.000000
# ..                             ...          ...         ...
# 109                             55     0.000000    0.018182
# 111                             93     0.000000    0.000000
# 112                           1501     0.000000    0.109260
# 84                           21710     0.000000    0.037771
# 83                              84     0.000000    0.000000
# 82                              43     0.000000    0.000000
# 67                             130     0.000000    0.007692
# 57                           30086     0.000000    0.105564
# 58                               2     0.000000    0.000000
# 59                           67309     0.000000    0.024425
# 60                            5505     0.000000    0.049591
# 61                            4283     0.000000    0.056269
# 62                           43683     0.000000    0.010462
# 63                              46     0.000000    0.000000
# 64                               2     0.000000    0.000000
# 65                               1     0.000000    0.000000
# 66                          185119     0.000000    0.174850
# 69                             542     0.000000    0.023985
# 81                              18     0.000000    0.166667
# 70                               3     0.000000    0.000000
# 71                               1     0.000000    0.000000
# 72                             110     0.000000    0.009091
# 73                               1     0.000000    0.000000
# 74                              49     0.000000    0.020408
# 75                             102     0.000000    0.039216
# 76                             165     0.000000    0.006061
# 77                               8     0.000000    0.000000
# 78                              37     0.000000    0.000000
# 80                             402     0.000000    0.007463
# 219                         399749     0.000000    0.104586
#
# [220 rows x 6 columns]
