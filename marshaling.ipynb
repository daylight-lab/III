# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# First, we'll start with a list of country names, ISO-3166 2- and 3- letter codes.

# %%
countries =\
pd.read_csv('shared/data/country-codes/countries_codes_and_coordinates.csv')\
    .drop(columns=['Latitude (average)', 'Longitude (average)'])
# remove extraneous quotes
countries['Alpha-2 code'] = countries['Alpha-2 code'].apply(lambda x: x.split("\"")[1])
countries['Alpha-3 code'] = countries['Alpha-3 code'].apply(lambda x: x.split("\"")[1])
countries['Numeric code'] = countries['Numeric code'].apply(lambda x: x.split("\"")[1])

# %%
countries.head()
# Out:
#           Country Alpha-2 code Alpha-3 code Numeric code
# 0     Afghanistan           AF          AFG            4
# 1         Albania           AL          ALB            8
# 2         Algeria           DZ          DZA           12
# 3  American Samoa           AS          ASM           16
# 4         Andorra           AD          AND           20

# %%
len(countries)
# Out:
# 257

# %% [markdown]
# ## Merge layer4 (alexa rankings) in

# %%
home_bias = pd\
    .read_csv('home-bias/analysis/levenshtein_from_global_ranking-2019-11-04.csv')\
    .rename(columns={
        'country': 'Country',
        'levenshtein_from_global_ranking': 'layer4-alexa-rankings',
    })\
    .drop(columns=['Unnamed: 0'])

home_bias.columns
# Out:
# Index(['Country', 'layer4-alexa-rankings'], dtype='object')

# %%
# Manually fix country names
home_bias.loc[home_bias['Country']=='Laos', 'Country'] = "Lao People's Democratic Republic"
home_bias.iloc[86]
# Out:
# Country                  Lao People's Democratic Republic
# layer4-alexa-rankings                                  47
# Name: 86, dtype: object

# %%
layer4_merged =\
    countries.merge(home_bias, how='left')

layer4_merged.head()
# Out:
#           Country Alpha-2 code Alpha-3 code Numeric code  \
# 0     Afghanistan           AF          AFG            4
# 1         Albania           AL          ALB            8
# 2         Algeria           DZ          DZA           12
# 3  American Samoa           AS          ASM           16
# 4         Andorra           AD          AND           20
#
#    layer4-alexa-rankings
# 0                   47.0
# 1                   46.0
# 2                   48.0
# 3                    NaN
# 4                    NaN

# %%
len(layer4_merged) #.groupby('Alpha-2 code').sum()
# Out:
# 257

# %% [markdown]
# ## Merge layer5 (data laws) in

# %%
data_laws = pd\
    .read_csv('data-locality-laws/analysis/categories-of-discrete-data-laws-on-books-2019-11-07.csv')\
    .rename(columns={'Discrete categories of data laws': 'layer5-discrete-categories-data-laws'})

data_laws.Country = data_laws.Country.apply(lambda x: x.capitalize())
data_laws.head()
# Out:
#      Country  layer5-discrete-categories-data-laws
# 0  Argentina                                    21
# 1  Australia                                    21
# 2    Austria                                    12
# 3    Belgium                                    12
# 4     Brazil                                    27

# %%
layer5_merged =\
    layer4_merged\
        .merge(data_laws, how='left')\

layer5_merged['layer5-discrete-categories-data-laws'] =\
    layer5_merged['layer5-discrete-categories-data-laws'].fillna(value=0)

len(layer5_merged)
# Out:
# 257

# %%
layer5_merged.head()
# Out:
#           Country Alpha-2 code Alpha-3 code Numeric code  \
# 0     Afghanistan           AF          AFG            4
# 1         Albania           AL          ALB            8
# 2         Algeria           DZ          DZA           12
# 3  American Samoa           AS          ASM           16
# 4         Andorra           AD          AND           20
#
#    layer4-alexa-rankings  layer5-discrete-categories-data-laws
# 0                   47.0                                   0.0
# 1                   46.0                                   0.0
# 2                   48.0                                   0.0
# 3                    NaN                                   0.0
# 4                    NaN                                   0.0

# %% [markdown]
# ## Merge layer2 (IPv6 adoption percentages) in

# %%
ipv6_adoption = pd\
    .read_csv('ipv4-to-ipv6-transition/data/ipv6-adoption.csv')\
    .rename(columns={
        'ISO-3166-1 Alpha2 code': 'Alpha-2 code',
        ' IPv6 adoption percent': 'layer2-ipv6-adoption'
    })\
    .drop(columns=[' Country name'])

# %%
layer2_merged =\
    layer5_merged\
        .merge(ipv6_adoption, how='left')

# %%
len(layer2_merged)
# Out:
# 257

# %%
layer2_merged[layer2_merged['Alpha-2 code']=='DE']
# Out:
#     Country Alpha-2 code Alpha-3 code Numeric code  layer4-alexa-rankings  \
# 83  Germany           DE          DEU          276                   47.0
#
#     layer5-discrete-categories-data-laws  layer2-ipv6-adoption
# 83                                  22.0                 45.38

# %% [markdown]
# ## Merge layer3 (network interference events) in

# %%
layer3 = pd\
    .read_csv('network-interference-events/data/interference-measurements-by-country-2019-sanity.csv')\
    .drop(columns={
        'num_anomaly',
        'num_confirmed_interference',
        'num_no_confirmed_interference',
#         'loose_rate',
        'strict_rate',
    })\
    .rename(columns={
        'country_code': "Alpha-2 code",
#         'strict_rate': 'layer3-network-interference-rate'
        'loose_rate': 'layer3-network-interference-rate'
    })
    
layer3.head()
# Out:
#   Alpha-2 code  layer3-network-interference-rate
# 0           AD                          0.000000
# 1           AE                          0.149814
# 2           AF                          0.027300
# 3           AG                          0.025000
# 4           AI                          0.000000

# %%
layer3_merged = layer2_merged.merge(layer3, how='left')

# %%
len(layer3_merged)
# Out:
# 257

# %% [markdown]
# # Write the final CSV
# This CSV file should contain all layer metrics associated with countries and country codes

# %%
layer3_merged.sort_values(by="layer3-network-interference-rate", ascending=False)
# Out:
#                                           Country Alpha-2 code Alpha-3 code  \
# 238                                       Ukraine           UA          UKR
# 185                                       Réunion           RE          REU
# 19                                        Belarus           BY          BLR
# 160                                   Netherlands           NL          NLD
# 28                                       Botswana           BW          BWA
# 104                                     Indonesia           ID          IDN
# 44                                          Chile           CL          CHL
# 170                                        Norway           NO          NOR
# 66                                          Egypt           EG          EGY
# 103                                         India           IN          IND
# 181                                        Poland           PL          POL
# 39                                         Canada           CA          CAN
# 45                                          China           CN          CHN
# 70                                        Estonia           EE          EST
# 200                                  Saudi Arabia           SA          SAU
# 105                     Iran, Islamic Republic of           IR          IRN
# 30                                         Brazil           BR          BRA
# 83                                        Germany           DE          DEU
# 176                              Papua New Guinea           PG          PNG
# 239                          United Arab Emirates           AE          ARE
# 188                                        Russia           RU          RUS
# 187                            Russian Federation           RU          RUS
# 76                                         France           FR          FRA
# 127                                       Liberia           LR          LBR
# 121                                        Kuwait           KW          KWT
# 27                         Bosnia and Herzegovina           BA          BIH
# 172                                      Pakistan           PK          PAK
# 114                                        Jordan           JO          JOR
# 241                                 United States           US          USA
# 58                                         Cyprus           CY          CYP
# ..                                            ...          ...          ...
# 89                                     Guadeloupe           GP          GLP
# 165                                         Niger           NE          NER
# 63                                       Dominica           DM          DMA
# 162                                 New Caledonia           NC          NCL
# 194              Saint Vincent and the Grenadines           VC          VCT
# 145                                       Mayotte           YT          MYT
# 3                                  American Samoa           AS          ASM
# 7                                      Antarctica           AQ          ATA
# 29                                  Bouvet Island           BV          BVT
# 46                               Christmas Island           CX          CXR
# 47                        Cocos (Keeling) Islands           CC          CCK
# 52                                   Cook Islands           CK          COK
# 72                    Falkland Islands (Malvinas)           FK          FLK
# 79                    French Southern Territories           TF          ATF
# 97              Heard Island and McDonald Islands           HM          HMD
# 118        Korea, Democratic People's Republic of           KP          PRK
# 157                                       Namibia           NA          NAM
# 161                          Netherlands Antilles           AN          ANT
# 167                                          Niue           NU          NIU
# 168                                Norfolk Island           NF          NFK
# 169                      Northern Mariana Islands           MP          MNP
# 180                                      Pitcairn           PN          PCN
# 190  Saint Helena, Ascension and Tristan da Cunha           SH          SHN
# 198                                    San Marino           SM          SMR
# 211  South Georgia and the South Sandwich Islands           GS          SGS
# 216                        Svalbard and Jan Mayen           SJ          SJM
# 228                                       Tokelau           TK          TKL
# 236                                        Tuvalu           TV          TUV
# 242          United States Minor Outlying Islands           UM          UMI
# 253                                Western Sahara           EH          ESH
#
#     Numeric code  layer4-alexa-rankings  layer5-discrete-categories-data-laws  \
# 238          804                   48.0                                   0.0
# 185          638                    NaN                                   0.0
# 19           112                   49.0                                   0.0
# 160          528                   46.0                                  12.0
# 28            72                   46.0                                   0.0
# 104          360                   49.0                                  25.0
# 44           152                   48.0                                  15.0
# 170          578                   45.0                                  12.0
# 66           818                   47.0                                   0.0
# 103          356                   46.0                                  32.0
# 181          616                   46.0                                  15.0
# 39           124                   47.0                                  21.0
# 45           156                   50.0                                  36.0
# 70           233                   48.0                                  11.0
# 200          682                   48.0                                   0.0
# 105          364                    NaN                                   0.0
# 30            76                   47.0                                  27.0
# 83           276                   47.0                                  22.0
# 176          598                   47.0                                   0.0
# 239          784                   48.0                                   0.0
# 188          643                   50.0                                  29.0
# 187          643                    NaN                                   0.0
# 76           250                   46.0                                  21.0
# 127          430                   48.0                                   0.0
# 121          414                   46.0                                   0.0
# 27            70                   48.0                                   0.0
# 172          586                   46.0                                  20.0
# 114          400                   48.0                                   0.0
# 241          840                   46.0                                   0.0
# 58           196                   48.0                                  10.0
# ..           ...                    ...                                   ...
# 89           312                   47.0                                   0.0
# 165          562                   48.0                                   0.0
# 63           212                    NaN                                   0.0
# 162          540                   47.0                                   0.0
# 194          670                    NaN                                   0.0
# 145          175                   48.0                                   0.0
# 3             16                    NaN                                   0.0
# 7             10                    NaN                                   0.0
# 29            74                    NaN                                   0.0
# 46           162                    NaN                                   0.0
# 47           166                    NaN                                   0.0
# 52           184                    NaN                                   0.0
# 72           238                    NaN                                   0.0
# 79           260                    NaN                                   0.0
# 97           334                    NaN                                   0.0
# 118          408                    NaN                                   0.0
# 157          516                   47.0                                   0.0
# 161          530                    NaN                                   0.0
# 167          570                    NaN                                   0.0
# 168          574                    NaN                                   0.0
# 169          580                    NaN                                   0.0
# 180          612                    NaN                                   0.0
# 190          654                    NaN                                   0.0
# 198          674                    NaN                                   0.0
# 211          239                    NaN                                   0.0
# 216          744                    NaN                                   0.0
# 228          772                    NaN                                   0.0
# 236          798                    NaN                                   0.0
# 242          581                    NaN                                   0.0
# 253          732                    NaN                                   0.0
#
#      layer2-ipv6-adoption  layer3-network-interference-rate
# 238                  2.22                          0.677461
# 185                 25.06                          0.458152
# 19                   0.03                          0.378002
# 160                 19.61                          0.347028
# 28                   0.00                          0.329746
# 104                  0.37                          0.297416
# 44                   0.10                          0.292924
# 170                 11.66                          0.283267
# 66                   2.06                          0.277223
# 103                 40.57                          0.272668
# 181                 11.44                          0.266883
# 39                  23.18                          0.249730
# 45                   1.37                          0.238782
# 70                  25.90                          0.204358
# 200                 15.69                          0.183966
# 105                  0.17                          0.183379
# 30                  29.34                          0.168204
# 83                  45.38                          0.168072
# 176                  0.00                          0.166667
# 239                 17.67                          0.149814
# 188                  4.02                          0.146166
# 187                  4.02                          0.146166
# 76                  37.85                          0.141892
# 127                  0.29                          0.133768
# 121                  0.00                          0.120678
# 27                   5.27                          0.112649
# 172                  0.07                          0.107828
# 114                  0.75                          0.101127
# 241                 35.87                          0.099775
# 58                   0.09                          0.096797
# ..                    ...                               ...
# 89                  24.54                          0.000000
# 165                  0.00                          0.000000
# 63                   0.00                          0.000000
# 162                  0.08                          0.000000
# 194                  0.00                          0.000000
# 145                 45.39                          0.000000
# 3                    0.00                               NaN
# 7                    0.00                               NaN
# 29                   0.00                               NaN
# 46                   0.00                               NaN
# 47                   0.00                               NaN
# 52                   0.00                               NaN
# 72                   0.00                               NaN
# 79                   0.00                               NaN
# 97                   0.00                               NaN
# 118                  0.00                               NaN
# 157                   NaN                               NaN
# 161                  0.00                               NaN
# 167                  0.00                               NaN
# 168                  0.00                               NaN
# 169                  0.00                               NaN
# 180                  0.00                               NaN
# 190                  0.00                               NaN
# 198                  0.00                               NaN
# 211                  0.00                               NaN
# 216                  0.00                               NaN
# 228                  0.00                               NaN
# 236                  0.00                               NaN
# 242                  0.00                               NaN
# 253                  0.00                               NaN
#
# [257 rows x 8 columns]

# %%
layer3_merged.to_csv('output/2019-layer-scores.csv')
