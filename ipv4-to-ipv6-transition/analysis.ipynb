# %%
import pandas as pd

# %% [markdown]
# We collected this data from [Google's dataset of IPv6 adoption](https://www.google.com/intl/en/ipv6/statistics.html#tab=per-country-ipv6-adoption),
# by running `googleIPv6PerCountryData.data.map(x => [x[0], x[1], x[2]]).map(x => x.join(',')).join('\n')` into the console and copying the result to the clipboard. We then save that file in `./data/ipv6-adoption.csv`, adding a header row.

# %%
pd.read_csv('data/ipv6-adoption.csv')
# Out:
#     ISO-3166-1 Alpha2 code            Country name   IPv6 adoption percent
# 0                       AF             Afghanistan                    0.06
# 1                       AL                 Albania                    0.00
# 2                       DZ                 Algeria                    0.00
# 3                       AS          American Samoa                    0.00
# 4                       AD                 Andorra                    0.00
# 5                       AO                  Angola                    0.00
# 6                       AI                Anguilla                    0.00
# 7                       AQ              Antarctica                    0.00
# 8                       AG       Antigua & Barbuda                    0.00
# 9                       AR               Argentina                    8.39
# 10                      AM                 Armenia                    3.08
# ...
