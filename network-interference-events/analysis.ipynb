# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
interference_events = pd.read_csv('data/interference-measurements-by-country-2019.csv')\
    .drop(columns='Unnamed: 0')

# %%
interference_events.head()
# Out:
#   probe_cc  total  confirmed_count  anomaly_count
# 0       AD     75              1.0            1.0
# 1       AE   6826              3.0            1.0
# 2       AF   1551              1.0            1.0
# 3       AG     48              1.0            1.0
# 4       AI     19              NaN            NaN

# %%
interference_events['strict_rate']=\
 inteference_events.apply(lambda row: row['confirmed_count']/row['total'], axis=1)

# %%
interference_events['loose_rate']=\
 inteference_events.apply(lambda row: (row['confirmed_count']+row['anomaly_count'])/row['total'], axis=1)

# %%
interference_events
# Out:
#     probe_cc    total  confirmed_count  anomaly_count   strict_rate  \
# 0         AD       75              1.0            1.0  1.333333e-02
# 1         AE     6826              3.0            1.0  4.394960e-04
# 2         AF     1551              1.0            1.0  6.447453e-04
# 3         AG       48              1.0            1.0  2.083333e-02
# 4         AI       19              NaN            NaN           NaN
# 5         AL     2180              1.0            1.0  4.587156e-04
# 6         AM     2449              1.0            1.0  4.083299e-04
# 7         AO     3373              1.0            1.0  2.964720e-04
# 8         AP       22              NaN            NaN           NaN
# 9         AR    19421              1.0            1.0  5.149065e-05
# 10        AS        2              NaN            NaN           NaN
# 11        AT    11276              1.0            1.0  8.868393e-05
# 12        AU  1179620              1.0            1.0  8.477306e-07
# ...

# %%
# %load ../helpers.py
import datetime
import json

def dated_filename (fn, ext='.csv'):
    today = datetime.date.today()
    return '{}-{}{}'.format(fn, today, ext)

def load_json (fn):
    with open(fn, 'r') as myfile:
        data=myfile.read()
    return json.loads(data)

# %%
interference_events.to_csv(dated_filename('analysis/interference-measurements-by-country-2019'))
